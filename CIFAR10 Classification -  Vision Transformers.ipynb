# %% [markdown]
# # CIFAR10 Image Classification with Vision Transformers

# %%
import torch 
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, random_split, DataLoader

from torchvision import datasets, transforms, models
import torchvision.transforms as transforms
from torch.utils.data import Dataset, random_split, DataLoader
from torchvision.utils import save_image

from torchsummary import summary

import spacy

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import os
import time
import math
from PIL import Image
import glob
from IPython.display import display

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
BATCH_SIZE = 128
LR = 5e-6
NUM_EPOCHES = 60

# %% [markdown]
# ## Preprocessing

# %%
mean, std = (0.5,), (0.5,)

transform = transforms.Compose([transforms.ToTensor(),
                                transforms.Normalize(mean, std)
                              ])

# %%
trainset = datasets.CIFAR10('data/CIFAR10/', download=True, train=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=BATCH_SIZE, shuffle=True)

testset = datasets.CIFAR10('data/CIFAR10/', download=True, train=False, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=BATCH_SIZE, shuffle=False)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
from models.transformer import ViT

# %%
image_size = 32
channel_size = 3
patch_size = 8
embed_size = 256
num_heads = 8
classes = 10
num_layers = 4
hidden_size = 128
dropout = 0.2

model = ViT(image_size, channel_size, patch_size, embed_size, num_heads, classes, num_layers, hidden_size, dropout=dropout).to(device)
model
# Out:
# ViT(
#   (dropout_layer): Dropout(p=0.2, inplace=False)
#   (embeddings): Linear(in_features=192, out_features=256, bias=True)
#   (encoders): ModuleList(
#     (0): VisionEncoder(
#       (norm1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#       (norm2): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#       (attention): MultiHeadAttention(
#         (dropout_layer): Dropout(p=0.2, inplace=False)
#         (Q): Linear(in_features=256, out_features=256, bias=True)
#         (K): Linear(in_features=256, out_features=256, bias=True)
#         (V): Linear(in_features=256, out_features=256, bias=True)
#         (linear): Linear(in_features=256, out_features=256, bias=True)
#       )
#       (mlp): Sequential(
#         (0): Linear(in_features=256, out_features=128, bias=True)
#         (1): GELU()
#         (2): Dropout(p=0.2, inplace=False)
#         (3): Linear(in_features=128, out_features=256, bias=True)
#         (4): Dropout(p=0.2, inplace=False)
#       )
#     )
#     (1): VisionEncoder(
#       (norm1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#       (norm2): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#       (attention): MultiHeadAttention(
#         (dropout_layer): Dropout(p=0.2, inplace=False)
#         (Q): Linear(in_features=256, out_features=256, bias=True)
#         (K): Linear(in_features=256, out_features=256, bias=True)
#         (V): Linear(in_features=256, out_features=256, bias=True)
#         (linear): Linear(in_features=256, out_features=256, bias=True)
#       )
#       (mlp): Sequential(
#         (0): Linear(in_features=256, out_features=128, bias=True)
#         (1): GELU()
#         (2): Dropout(p=0.2, inplace=False)
#         (3): Linear(in_features=128, out_features=256, bias=True)
#         (4): Dropout(p=0.2, inplace=False)
#       )
#     )
#     (2): VisionEncoder(
#       (norm1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#       (norm2): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#       (attention): MultiHeadAttention(
#         (dropout_layer): Dropout(p=0.2, inplace=False)
#         (Q): Linear(in_features=256, out_features=256, bias=True)
#         (K): Linear(in_features=256, out_features=256, bias=True)
#         (V): Linear(in_features=256, out_features=256, bias=True)
#         (linear): Linear(in_features=256, out_features=256, bias=True)
#       )
#       (mlp): Sequential(
#         (0): Linear(in_features=256, out_features=128, bias=True)
#         (1): GELU()
#         (2): Dropout(p=0.2, inplace=False)
#         (3): Linear(in_features=128, out_features=256, bias=True)
#         (4): Dropout(p=0.2, inplace=False)
#       )
#     )
#     (3): VisionEncoder(
#       (norm1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#       (norm2): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#       (attention): MultiHeadAttention(
#         (dropout_layer): Dropout(p=0.2, inplace=False)
#         (Q): Linear(in_features=256, out_features=256, bias=True)
#         (K): Linear(in_features=256, out_features=256, bias=True)
#         (V): Linear(in_features=256, out_features=256, bias=True)
#         (linear): Linear(in_features=256, out_features=256, bias=True)
#       )
#       (mlp): Sequential(
#         (0): Linear(in_features=256, out_features=128, bias=True)
#         (1): GELU()
#         (2): Dropout(p=0.2, inplace=False)
#         (3): Linear(in_features=128, out_features=256, bias=True)
#         (4): Dropout(p=0.2, inplace=False)
#       )
#     )
#   )
#   (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#   (classifier): Sequential(
#     (0): Linear(in_features=256, out_features=10, bias=True)
#   )
# )

# %%
for img, label in trainloader:
    img = img.to(device)
    label = label.to(device)
    
    print("Input Image Dimensions: {}".format(img.size()))
    print("Label Dimensions: {}".format(label.size()))
    print("-"*100)
    
    out = model(img)
    
    print("Output Dimensions: {}".format(out.size()))
    break
# Out:
# Input Image Dimensions: torch.Size([128, 3, 32, 32])
# Label Dimensions: torch.Size([128])
# ----------------------------------------------------------------------------------------------------
# Output Dimensions: torch.Size([128, 10])

# %%
criterion = nn.NLLLoss()
optimizer = torch.optim.Adam(params=model.parameters(), lr=LR, betas=(0.9, 0.999), weight_decay=0.1)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer)

# %%
loss_hist = {}
loss_hist["train accuracy"] = []
loss_hist["train loss"] = []

for epoch in range(1, NUM_EPOCHES+1):
    model.train()
    
    epoch_train_loss = 0
        
    y_true_train = []
    y_pred_train = []
        
    for batch_idx, (img, labels) in enumerate(trainloader):
        img = img.to(device)
        labels = labels.to(device)
        
        preds = model(img)
        
        loss = criterion(preds, labels)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        y_pred_train.extend(preds.detach().argmax(dim=-1).tolist())
        y_true_train.extend(labels.detach().tolist())
            
        epoch_train_loss += loss.item()
    
    scheduler.step(epoch_train_loss)
    
    loss_hist["train loss"].append(epoch_train_loss)
    
    total_correct = len([True for x, y in zip(y_pred_train, y_true_train) if x==y])
    total = len(y_pred_train)
    accuracy = total_correct * 100 / total
    
    loss_hist["train accuracy"].append(accuracy)
    
    print("-------------------------------------------------")
    print("Epoch: {} Train mean loss: {:.8f}".format(epoch, epoch_train_loss))
    print("       Train Accuracy%: ", accuracy, "==", total_correct, "/", total)
    print("-------------------------------------------------")
# Out:
# -------------------------------------------------
# Epoch: 1 Train mean loss: 937.02618241
#        Train Accuracy%:  11.854 == 5927 / 50000
# -------------------------------------------------
# -------------------------------------------------
# Epoch: 2 Train mean loss: 907.48732972
#        Train Accuracy%:  12.802 == 6401 / 50000
# -------------------------------------------------
# -------------------------------------------------
# Epoch: 3 Train mean loss: 900.30987263
#        Train Accuracy%:  13.426 == 6713 / 50000
# -------------------------------------------------
# -------------------------------------------------
# Epoch: 4 Train mean loss: 897.16369438
#        Train Accuracy%:  13.526 == 6763 / 50000
# -------------------------------------------------
# -------------------------------------------------
# Epoch: 5 Train mean loss: 894.98550820
#        Train Accuracy%:  13.952 == 6976 / 50000
# -------------------------------------------------
# -------------------------------------------------
# Epoch: 6 Train mean loss: 892.67564750
#        Train Accuracy%:  14.186 == 7093 / 50000
# -------------------------------------------------
# -------------------------------------------------
# Epoch: 7 Train mean loss: 891.92693758
#        Train Accuracy%:  14.106 == 7053 / 50000
# -------------------------------------------------
# -------------------------------------------------
# Epoch: 8 Train mean loss: 891.28419876
#        Train Accuracy%:  14.192 == 7096 / 50000
# -------------------------------------------------
# -------------------------------------------------
# Epoch: 9 Train mean loss: 891.20374060
#        Train Accuracy%:  14.294 == 7147 / 50000
# -------------------------------------------------
# -------------------------------------------------
# Epoch: 10 Train mean loss: 890.90023589
#        Train Accuracy%:  14.078 == 7039 / 50000
# -------------------------------------------------
# -------------------------------------------------
# Epoch: 11 Train mean loss: 890.48158002
#        Train Accuracy%:  14.34 == 7170 / 50000
# -------------------------------------------------
# -------------------------------------------------
# Epoch: 12 Train mean loss: 890.62054849
#        Train Accuracy%:  14.122 == 7061 / 50000
# -------------------------------------------------
# -------------------------------------------------
# Epoch: 13 Train mean loss: 890.73440218
#        Train Accuracy%:  14.056 == 7028 / 50000
# -------------------------------------------------
# -------------------------------------------------
# Epoch: 14 Train mean loss: 890.06518960
#        Train Accuracy%:  14.046 == 7023 / 50000
# -------------------------------------------------
# -------------------------------------------------
# Epoch: 15 Train mean loss: 890.77825284
#        Train Accuracy%:  14.072 == 7036 / 50000
# -------------------------------------------------
# -------------------------------------------------
# Epoch: 16 Train mean loss: 890.57436419
#        Train Accuracy%:  14.112 == 7056 / 50000
# -------------------------------------------------
# -------------------------------------------------
# Epoch: 17 Train mean loss: 891.09687543
#        Train Accuracy%:  13.976 == 6988 / 50000
# -------------------------------------------------
# -------------------------------------------------
# Epoch: 18 Train mean loss: 891.34806538
#        Train Accuracy%:  13.892 == 6946 / 50000
# -------------------------------------------------
# -------------------------------------------------
# Epoch: 19 Train mean loss: 891.45660710
#        Train Accuracy%:  13.674 == 6837 / 50000
# -------------------------------------------------
# -------------------------------------------------
# Epoch: 20 Train mean loss: 891.17673326
#        Train Accuracy%:  13.604 == 6802 / 50000
# -------------------------------------------------
# -------------------------------------------------
# Epoch: 21 Train mean loss: 890.53406882
#        Train Accuracy%:  13.754 == 6877 / 50000
# -------------------------------------------------
# -------------------------------------------------
# Epoch: 22 Train mean loss: 891.47452450
#        Train Accuracy%:  13.662 == 6831 / 50000
# -------------------------------------------------
# -------------------------------------------------
# Epoch: 23 Train mean loss: 891.37538290
#        Train Accuracy%:  13.47 == 6735 / 50000
# -------------------------------------------------
# -------------------------------------------------
# Epoch: 24 Train mean loss: 891.09069896
#        Train Accuracy%:  13.718 == 6859 / 50000
# -------------------------------------------------
# -------------------------------------------------
# Epoch: 25 Train mean loss: 891.39458632
#        Train Accuracy%:  13.548 == 6774 / 50000
# -------------------------------------------------
# -------------------------------------------------
# Epoch: 26 Train mean loss: 891.28167868
#        Train Accuracy%:  13.558 == 6779 / 50000
# -------------------------------------------------
# -------------------------------------------------
# Epoch: 27 Train mean loss: 891.27132034
#        Train Accuracy%:  13.528 == 6764 / 50000
# -------------------------------------------------
# -------------------------------------------------
# Epoch: 28 Train mean loss: 891.12116170
#        Train Accuracy%:  13.604 == 6802 / 50000
# -------------------------------------------------
# -------------------------------------------------
# Epoch: 29 Train mean loss: 891.20103288
#        Train Accuracy%:  13.544 == 6772 / 50000
# -------------------------------------------------
# -------------------------------------------------
# Epoch: 30 Train mean loss: 891.94500923
#        Train Accuracy%:  13.35 == 6675 / 50000
# -------------------------------------------------
# -------------------------------------------------
# Epoch: 31 Train mean loss: 890.78844357
#        Train Accuracy%:  13.832 == 6916 / 50000
# -------------------------------------------------
# -------------------------------------------------
# Epoch: 32 Train mean loss: 891.39558578
#        Train Accuracy%:  13.718 == 6859 / 50000
# -------------------------------------------------
# -------------------------------------------------
# Epoch: 33 Train mean loss: 891.51200628
#        Train Accuracy%:  13.498 == 6749 / 50000
# -------------------------------------------------
# -------------------------------------------------
# Epoch: 34 Train mean loss: 890.67962790
#        Train Accuracy%:  13.716 == 6858 / 50000
# -------------------------------------------------
# -------------------------------------------------
# Epoch: 35 Train mean loss: 891.31423140
#        Train Accuracy%:  13.672 == 6836 / 50000
# -------------------------------------------------
# -------------------------------------------------
# Epoch: 36 Train mean loss: 891.62424970
#        Train Accuracy%:  13.522 == 6761 / 50000
# -------------------------------------------------
# -------------------------------------------------
# Epoch: 37 Train mean loss: 891.72963786
#        Train Accuracy%:  13.63 == 6815 / 50000
# -------------------------------------------------
# -------------------------------------------------
# Epoch: 38 Train mean loss: 892.25483394
#        Train Accuracy%:  13.564 == 6782 / 50000
# -------------------------------------------------
# -------------------------------------------------
# Epoch: 39 Train mean loss: 891.52492690
#        Train Accuracy%:  13.416 == 6708 / 50000
# -------------------------------------------------
# -------------------------------------------------
# Epoch: 40 Train mean loss: 890.90819693
#        Train Accuracy%:  13.88 == 6940 / 50000
# -------------------------------------------------
# -------------------------------------------------
# Epoch: 41 Train mean loss: 891.13869643
#        Train Accuracy%:  13.632 == 6816 / 50000
# -------------------------------------------------
# -------------------------------------------------
# Epoch: 42 Train mean loss: 891.19398618
#        Train Accuracy%:  13.804 == 6902 / 50000
# -------------------------------------------------
# -------------------------------------------------
# Epoch: 43 Train mean loss: 890.76588154
#        Train Accuracy%:  13.62 == 6810 / 50000
# -------------------------------------------------
# -------------------------------------------------
# Epoch: 44 Train mean loss: 891.70182872
#        Train Accuracy%:  13.676 == 6838 / 50000
# -------------------------------------------------
# -------------------------------------------------
# Epoch: 45 Train mean loss: 891.42134476
#        Train Accuracy%:  13.346 == 6673 / 50000
# -------------------------------------------------
# -------------------------------------------------
# Epoch: 46 Train mean loss: 891.52566004
#        Train Accuracy%:  13.576 == 6788 / 50000
# -------------------------------------------------
# -------------------------------------------------
# Epoch: 47 Train mean loss: 891.50563240
#        Train Accuracy%:  13.574 == 6787 / 50000
# -------------------------------------------------
# -------------------------------------------------
# Epoch: 48 Train mean loss: 891.85856938
#        Train Accuracy%:  13.164 == 6582 / 50000
# -------------------------------------------------
# -------------------------------------------------
# Epoch: 49 Train mean loss: 890.64270496
#        Train Accuracy%:  13.898 == 6949 / 50000
# -------------------------------------------------
# -------------------------------------------------
# Epoch: 50 Train mean loss: 891.52316165
#        Train Accuracy%:  13.5 == 6750 / 50000
# -------------------------------------------------
# -------------------------------------------------
# Epoch: 51 Train mean loss: 891.35366464
#        Train Accuracy%:  13.638 == 6819 / 50000
# -------------------------------------------------
# -------------------------------------------------
# Epoch: 52 Train mean loss: 891.00204396
#        Train Accuracy%:  13.7 == 6850 / 50000
# -------------------------------------------------
# -------------------------------------------------
# Epoch: 53 Train mean loss: 890.88533974
#        Train Accuracy%:  13.676 == 6838 / 50000
# -------------------------------------------------
# -------------------------------------------------
# Epoch: 54 Train mean loss: 890.95705009
#        Train Accuracy%:  13.646 == 6823 / 50000
# -------------------------------------------------
# -------------------------------------------------
# Epoch: 55 Train mean loss: 891.69542742
#        Train Accuracy%:  13.49 == 6745 / 50000
# -------------------------------------------------
# -------------------------------------------------
# Epoch: 56 Train mean loss: 890.94774032
#        Train Accuracy%:  13.732 == 6866 / 50000
# -------------------------------------------------
# -------------------------------------------------
# Epoch: 57 Train mean loss: 890.91498804
#        Train Accuracy%:  13.87 == 6935 / 50000
# -------------------------------------------------
# -------------------------------------------------
# Epoch: 58 Train mean loss: 891.39634633
#        Train Accuracy%:  13.734 == 6867 / 50000
# -------------------------------------------------
# -------------------------------------------------
# Epoch: 59 Train mean loss: 891.01257443
#        Train Accuracy%:  13.604 == 6802 / 50000
# -------------------------------------------------
# -------------------------------------------------
# Epoch: 60 Train mean loss: 891.21284413
#        Train Accuracy%:  13.75 == 6875 / 50000
# -------------------------------------------------

# %%
plt.plot(loss_hist["train accuracy"])
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.show()

# %%
plt.plot(loss_hist["train loss"])
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.show()

# %%
with torch.no_grad():
    model.eval()
    
    y_true_test = []
    y_pred_test = []
    
    for batch_idx, (img, labels) in enumerate(testloader):
        img = img.to(device)
        label = label.to(device)
    
        preds = model(img)
        
        y_pred_test.extend(preds.detach().argmax(dim=-1).tolist())
        y_true_test.extend(labels.detach().tolist())
        
    total_correct = len([True for x, y in zip(y_pred_test, y_true_test) if x==y])
    total = len(y_pred_test)
    accuracy = total_correct * 100 / total
    
    print("Test Accuracy%: ", accuracy, "==", total_correct, "/", total)
# Out:
# Test Accuracy%:  14.91 == 1491 / 10000
